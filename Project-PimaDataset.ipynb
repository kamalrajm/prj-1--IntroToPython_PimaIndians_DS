# %% [markdown]
# 1. Enable plotting graphs in Jupyter notebook
# 2. Import the libraries- pandas, numpy, matplotlib, seaborn, sklearn, train_test_split

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
sns.set(style="darkgrid")
# %matplotlib inline

# %% [markdown]
# #3. Import the dataset
# #4.Check first 6 records and last 7 records

# %%
dfpima = pd.read_csv("diabetes.csv")   
dfpima.head(6)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0

# %%
dfpima.tail(7)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
dfpima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# #5. As our data is numeric, check if columns has any other value rather than numeric

# %%
dfpima.applymap(np.isreal)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           True     True           True           True     True  True
# 1           True     True           True           True     True  True
# 2           True     True           True           True     True  True
# 3           True     True           True           True     True  True
# 4           True     True           True           True     True  True
# 5           True     True           True           True     True  True
# 6           True     True           True           True     True  True
# 7           True     True           True           True     True  True
# 8           True     True           True           True     True  True
# 9           True     True           True           True     True  True
# 10          True     True           True           True     True  True
# 11          True     True           True           True     True  True
# ...

# %% [markdown]
# #6. Check distribution of various variables in the dataset

# %%
dfpima.hist(figsize=(10,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002C2176BCB00>,
# ...
#       dtype=object)

# %%
dfpima.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dfpima.describe().transpose()
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %% [markdown]
# #7. Find the outcome types (0/1) count for other independent columns something like table

# %%
dfpima.groupby(["Outcome"]).count()
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# Outcome
# 0                500      500            500            500      500  500
# 1                268      268            268            268      268  268
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                             500  500
# 1                             268  268

# %% [markdown]
# #8. Find the dimenson of the dataset- pima_df.shape

# %%
dfpima.shape
# Out:
# (768, 9)

# %% [markdown]
# #9. Create a pairplot of the dataset. Hue should be on the dependent variable

# %%
sns.pairplot(dfpima,hue='Outcome')
# Out:
# D:\DataScience\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# D:\DataScience\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# DataSet Outliars
# 10. Which all independent variables are skewed

# %%
dfpima.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %% [markdown]
# ## Count of Missing Values (Zeros) of Independent Variables

# %%
print("Glucose: ",(dfpima['Glucose']==0).values.sum())              
print("BloodPressure: ",(dfpima['BloodPressure']==0).values.sum())  
print("SkinThickness: ",(dfpima['SkinThickness']==0).values.sum())  
print("Insulin: ",(dfpima['Insulin']==0).values.sum())              
print("BMI: ",(dfpima['BMI']==0).values.sum())
# Out:
# Glucose:  5
# BloodPressure:  35
# SkinThickness:  227
# Insulin:  374
# BMI:  11

# %% [markdown]
# ## Descriptive Statistics
# #Normal Glucose Range is between 70 and 100 milligrams per deciliter.
# #The normal blood pressure of a human is usually between 90-120 mmHg systolic and 60–80 mmHg diastolic
# #For the average adult human, the skin has a surface area of between 1.5-2.0 square metres (16.1-21.5 sq ft.)
# #Normal Insulin range from < 174 pmol/L to 125-1917 pmol/L
# #Normal BMI normal weight: 18.5 to 25, overweight: 25 to 30, obese: over 30.

# %%
print("Mean Glucose:", dfpima['Glucose'].mean())
print("Median Glucose:", dfpima['Glucose'].median())
print("Mode Glucose:", dfpima['Glucose'].mode())
print('------------------------------------------')
print("Mean BloodPressure:", dfpima['BloodPressure'].mean())
print("Median BloodPressure:", dfpima['BloodPressure'].median())
print("Mode BloodPressure:", dfpima['BloodPressure'].mode())
print('------------------------------------------')
print("Mean SkinThickness:", dfpima['SkinThickness'].mean())
print("Median SkinThickness:", dfpima['SkinThickness'].median())
print("Mode SkinThickness:", dfpima['SkinThickness'].mode())
print('------------------------------------------')
print("Mean Insulin:", dfpima['Insulin'].mean())
print("Median Insulin:", dfpima['Insulin'].median())
print("Mode Insulin:", dfpima['Insulin'].mode())
print('------------------------------------------')
print("Mean BMI:", dfpima['BMI'].mean())
print("Median BMI:", dfpima['BMI'].median())
print("Mode BMI:", dfpima['BMI'].mode())
print('------------------------------------------')
print("Mean Age:", dfpima['Age'].mean())
print("Median Age:", dfpima['Age'].median())
print("Mode Age:", dfpima['Age'].mode())
# Out:
# Mean Glucose: 120.89453125
# Median Glucose: 117.0
# Mode Glucose: 0     99
# 1    100
# dtype: int64
# ------------------------------------------
# Mean BloodPressure: 69.10546875
# Median BloodPressure: 72.0
# Mode BloodPressure: 0    70
# dtype: int64
# ------------------------------------------
# Mean SkinThickness: 20.536458333333332
# Median SkinThickness: 23.0
# Mode SkinThickness: 0    0
# dtype: int64
# ------------------------------------------
# Mean Insulin: 79.79947916666667
# Median Insulin: 30.5
# Mode Insulin: 0    0
# dtype: int64
# ------------------------------------------
# Mean BMI: 31.992578124999977
# Median BMI: 32.0
# Mode BMI: 0    32.0
# dtype: float64
# ------------------------------------------
# Mean Age: 33.240885416666664
# Median Age: 29.0
# Mode Age: 0    22
# dtype: int64

# %% [markdown]
#     11. Which all variables are normally distributed- plas, pres, skin, and mass

# %%
sns.distplot(dfpima['BMI'], rug=True)   # Many women samples are Overweight/Obesity as per the BMI.Also it is normally distributed
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(dfpima['Insulin'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(dfpima['SkinThickness']) # if missing values (Zeros) data are removed it is normally distributed

# %%
sns.distplot(dfpima['BloodPressure'],rug= True)

# %%
sns.jointplot(dfpima['BMI'],dfpima['Age'], kind='hex') # The women from Age 20 to 40 are over weight to Obese.

# %%
dfpima.groupby('Outcome').hist()
# Out:
# Outcome
# 0    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# 1    [[AxesSubplot(0.125,0.670278;0.215278x0.209722...
# dtype: object

# %%
sns.jointplot(dfpima['Pregnancies'],dfpima['BloodPressure'], kind='resid')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(dfpima['Glucose'],dfpima['Insulin'], kind= "resid")  # From the graph , there are quite few set of women who have large glucose values even taken insulin
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(dfpima[['Glucose','Insulin', 'Age', 'BMI', 'BloodPressure', 'Pregnancies','DiabetesPedigreeFunction']])

# %%
sns.pairplot(dfpima[['BMI','Outcome', 'Age','SkinThickness']])

# %% [markdown]
# #12. Create a boxplot which should be grouped by outcome. The layout should be 3x4

# %%
dfpima.boxplot(by ='Outcome', layout=(3,4), figsize=(10,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002C23D6E3E80>,
# ...
#       dtype=object)

# %%
dfpima.boxplot(column="Pregnancies", by="Outcome")

# %%
dfpima.boxplot(column="Glucose", by="Outcome")

# %%
dfpima.boxplot(column="BloodPressure", by="Outcome")

# %%
dfpima.boxplot(column="Insulin", by="Outcome")

# %%
dfpima.boxplot(column="BMI", by="Outcome")

# %%
dfpima.boxplot(column="DiabetesPedigreeFunction", by="Outcome")

# %%
dfpima.boxplot(column="Age", by="Outcome")

# %% [markdown]
# #13. Create a histogram for Age column

# %%
dfpima.hist(by="Outcome", column="Age")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002073F04DA90>,
# ...
#       dtype=object)

# %%
sns.distplot(dfpima['Age'], rug=True)  # Most women have 20 to 50 in Age in this dataset.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
#  #14. Create a new dataframe called "pima_df_z" which should have all the column of "pima_df" except the dependent variable

# %%
pima_df_z= dfpima.loc[:,'Pregnancies':'Age']
pima_df_z
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %% [markdown]
# #15. Add a new column in the new dataframe with name "log_age" which should be the log value of "Age" column
# #16 Repeat the same for "Insulin" [log_test] and "Pregnancies" [log_preg] columns as well

# %%
pima_df_z['log_age'] = np.log(dfpima['Age'])
pima_df_z['log_test'] = np.log(dfpima['Insulin'])
pima_df_z['log_preg'] = np.log(dfpima['Pregnancies'])
pima_df_z
# Out:
# D:\DataScience\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# D:\DataScience\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# ...

# %%
pima_df_z = pima_df_z.replace([np.inf, -np.inf], 0.0)  # Replaced inf values with 0
pima_df_z
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %% [markdown]
# 17.Now create the histogram for "log_age", "log_preg", "log_test" column

# %%
pima_df_z.hist('log_age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000207409BFF28>]],
#       dtype=object)

# %%
pima_df_z.hist('log_test')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020740A24438>]],
#       dtype=object)

# %%
pima_df_z.hist('log_preg')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020740AAB1D0>]],
#       dtype=object)

# %% [markdown]
# #18. Create a scatter plot for "log_test" and "Outcome" variables

# %%
sns.scatterplot(x= pima_df_z['log_test'],y= pima_df_z['log_age'], hue= dfpima['Outcome'])

# %%
sns.lmplot(x= 'BMI', y= 'Insulin',data= dfpima)

# %%
sns.swarmplot(dfpima['Outcome'],dfpima['Age'])

# %%
corr = dfpima.corr()
corr
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.heatmap(corr, annot=True)

# %% [markdown]
# 19. Draw the conclusion
#
# Characteristics:
#
# #1.The population is generally between 20 to 50 years old.
# #2.Many attributes have a zero value exist seem to be errors in the data (e.g. BP, SkinThickness, insulin, and BMI).
# #3.Some of the attributes look normally distributed (BP, SkinThickness, and BMI).
# #4.Age should probably have a normal distribution, the constraints on the data collection may have skewed the distribution.
# #5.There are less skewness between Glucose and Skinthickness
#
# Conclusion:
#
# #1.The dataset is biased as it is having many missing values/zeros.
# #2.There is not much relationship between age to diabetes.
# #3.Also there is not much relationship between pedi function to diabetes.
# #4.When compared to outcome of correlation there is combined possibility of Glucose , BMI & Age may made many Pima tribe to become diabetics positive.
